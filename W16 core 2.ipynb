# %% [markdown]
# # Assignment:
#
# Your task is to engineer some new features to try to improve a model's ability to predict the total number of bike share rentals during a given hour of the day.
#
# 1. Import the data the drop the 'casual' and 'registered' columns. These are redundant with your target, 'count'.
# 2. Transform the 'datetime' column into a datetime type and use it to create 3 new columns in the data frame containing the:
#     1. Name of the Month
#     2. Name of the Day of the Week
#     3. Hour of the Day
#         1. Make sure all 3 new columns are 'object' datatype so they can be one-hot encoded later.
#         2. Drop the 'datetime' and 'season' columns. These are now redundant.
# 3. The temperatures in the 'temp' and 'atemp' columns are in Celsius. Use `.apply()` and a Lambda function to convert them to Fahrenheit.
# 4. Create a new column, 'temp_variance,' which shows how much warmer or colder the current temperature ('temp') is than the average temperate for that day of the year ('atemp'). If the current temperature is warmer than average ('atemp'), the value in 'temp_variance' should be positive.
# Drop the 'atemp' column.
#
# ### Optional:
#
# Use a predictive model of your choice and try to predict the 'count' of hourly bike-share users with both the original features and the engineered feature set you created.
#
# Remember to drop the 'casual' and 'registered' columns from both versions before modeling.
#
# Did these feature engineering choices improve your ability to predict the 'count'?

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
fpath = "Data/bikeshare_train - bikeshare_train.csv"

df=pd.read_csv(fpath)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df=df.drop(columns=['casual', 'registered'])
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %%
df.sample(10)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 7156   2012-04-16 13:00:00       2        1           0        1  30.34
# 4834   2011-11-14 12:00:00       4        0           1        1  22.96
# 10493  2012-12-03 15:00:00       4        0           1        1  24.60
# 796    2011-02-16 15:00:00       1        0           1        1  18.86
# 1157   2011-03-12 21:00:00       1        0           0        1  15.58
# 6309    2012-02-19 3:00:00       1        0           0        2  12.30
# 4672   2011-11-07 18:00:00       4        0           1        1  18.86
# 7920    2012-06-10 9:00:00       2        0           0        1  28.70
# 10530   2012-12-05 4:00:00       4        0           1        1  20.50
# 5089    2011-12-06 3:00:00       4        0           1        2  18.86
#
#         atemp  humidity  windspeed  count
# 7156   33.335        45    19.9995    263
# 4834   26.515        56    19.9995    202
# 10493  31.060        56     0.0000    268
# 796    22.725        28    27.9993    117
# 1157   19.695        62     0.0000     82
# 6309   14.395        36    15.0013     15
# 4672   22.725        59     7.0015    425
# 7920   32.575        58     0.0000    266
# 10530  24.240        63    30.0026     10
# 5089   22.725        87    12.9980      3

# %%
df['datetime']=pd.to_datetime(df['datetime'], format='%Y-%m-%d %H:%M:%S')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 850.6 KB
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %%
df['year']=df['datetime'].dt.year
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count  year
# 0        81        0.0     16  2011
# 1        80        0.0     40  2011
# 2        80        0.0     32  2011
# 3        75        0.0     13  2011
# 4        75        0.0      1  2011

# %%
df['day_name']=df['datetime'].dt.day_name()

# %%
df['hour']=df['datetime'].dt.hour
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count  year  day_name  hour
# 0        81        0.0     16  2011  Saturday     0
# 1        80        0.0     40  2011  Saturday     1
# 2        80        0.0     32  2011  Saturday     2
# 3        75        0.0     13  2011  Saturday     3
# 4        75        0.0      1  2011  Saturday     4

# %%
df=df.drop(columns=['datetime','season'])
df.head()
# Out:
#    holiday  workingday  weather  temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  9.84  14.395        81        0.0     16
# 1        0           0        1  9.02  13.635        80        0.0     40
# 2        0           0        1  9.02  13.635        80        0.0     32
# 3        0           0        1  9.84  14.395        75        0.0     13
# 4        0           0        1  9.84  14.395        75        0.0      1
#
#    year  day_name  hour
# 0  2011  Saturday     0
# 1  2011  Saturday     1
# 2  2011  Saturday     2
# 3  2011  Saturday     3
# 4  2011  Saturday     4

# %%
df['temp']=df['temp'].apply(lambda x: x*9/5 + 32)

# %%
df['atemp']=df['atemp'].apply(lambda x: x*9/5 + 32)
df.head()
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81        0.0     16
# 1        0           0        1  48.236  56.543        80        0.0     40
# 2        0           0        1  48.236  56.543        80        0.0     32
# 3        0           0        1  49.712  57.911        75        0.0     13
# 4        0           0        1  49.712  57.911        75        0.0      1
#
#    year  day_name  hour
# 0  2011  Saturday     0
# 1  2011  Saturday     1
# 2  2011  Saturday     2
# 3  2011  Saturday     3
# 4  2011  Saturday     4

# %%
df['temp_variance']=df['temp'] - df['atemp']

# %%
df=df.drop(columns=['atemp'])
df.head()
# Out:
#    holiday  workingday  weather    temp  humidity  windspeed  count  year  \
# 0        0           0        1  49.712        81        0.0     16  2011
# 1        0           0        1  48.236        80        0.0     40  2011
# 2        0           0        1  48.236        80        0.0     32  2011
# 3        0           0        1  49.712        75        0.0     13  2011
# 4        0           0        1  49.712        75        0.0      1  2011
#
#    day_name  hour  temp_variance
# 0  Saturday     0         -8.199
# 1  Saturday     1         -8.307
# 2  Saturday     2         -8.307
# 3  Saturday     3         -8.199
# 4  Saturday     4         -8.199

# %%
column="temp_variance"
move = df.pop(column)
df.insert(4,column,move)
df.head()
# Out:
#    holiday  workingday  weather    temp  temp_variance  humidity  windspeed  \
# 0        0           0        1  49.712         -8.199        81        0.0
# 1        0           0        1  48.236         -8.307        80        0.0
# 2        0           0        1  48.236         -8.307        80        0.0
# 3        0           0        1  49.712         -8.199        75        0.0
# 4        0           0        1  49.712         -8.199        75        0.0
#
#    count  year  day_name  hour
# 0     16  2011  Saturday     0
# 1     40  2011  Saturday     1
# 2     32  2011  Saturday     2
# 3     13  2011  Saturday     3
# 4      1  2011  Saturday     4

# %%
column='year'
move=df.pop(column)
df.insert(0,column,move)

# %%
column = 'day_name'
move=df.pop(column)
df.insert(1,column,move)

# %%
column = 'hour'
move = df.pop(column)
df.insert(2,column,move)
df.head()
# Out:
#    year  day_name  hour  holiday  workingday  weather    temp  temp_variance  \
# 0  2011  Saturday     0        0           0        1  49.712         -8.199
# 1  2011  Saturday     1        0           0        1  48.236         -8.307
# 2  2011  Saturday     2        0           0        1  48.236         -8.307
# 3  2011  Saturday     3        0           0        1  49.712         -8.199
# 4  2011  Saturday     4        0           0        1  49.712         -8.199
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1
